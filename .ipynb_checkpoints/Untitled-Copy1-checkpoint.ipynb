# %% [markdown]
# Задание 1:
# Посчитайте частные производные функций (как обычно, необходимо решение на бумажке или в LaTeX и на numpy):
#
# 1) f(x,y)=2x^2y^3 + 1/x + y^2x + 7, а для этой функции также градиент в точке (1,2)
# - решение:
#     f'x = 4*x*(y**3)- 1/(x*x) + (y*y)- частная производная по х
#     f'y = 6*(x*x)*(y*y) +2yx  - частная производная по y
#
#     f'x(1,2)= 4*1*(2**3) -1/(1*1) + (2*2) = 35  значение частной производной по х в точки (1,2)
#     f'y(1,2)= 6*(1*1)*(2*2) + 2*2*1 = 28  значение частной производной по у в точки (1,2)
#
#     grad (1,2) = (4,8)

# %%
import numpy as np
from scipy.optimize import approx_fprime
from sympy import diff, symbols, cos, sin
import math as math

# %%
# 1.
def f(x, c0, c1):
    return c0*(x[0]**2)*x[1]**3 + 1/x[0] + (x[1]**2)*x[0] +c1

# %%
x = np.array([1,2])
c0, c1 = (2,7)
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, f, [eps, eps], c0, c1)

# Градиент функции в точки (1,2) совпадает с результатом ручного вычисления!
# Out:
# array([35.00000024, 28.00000024])

# %% [markdown]
# **2) f(x,y)=x^2y - sin(xy) + cos(x^2) + 6y**
#
# решение:
#     f'x = 2*xy - y*cos(xy) - 2*sin(x)*cos(x) - частная производная по х
#     f'y = x*x - x*cos(xy) + 6   - частная производная по y
#
#     f'x(1,2) = 2*1*2 - 2*cos(2) - 2*sin(1)*cos(1) = 3,9 значение частной производной по х в точки (1,2)
#     f'y(1,2) = 1 -1*cos(2) +6 = 7,416 значение частной производной по у в точки (1,2)

# %%
# 2.
def f2(x, c0, c1):
    return c0*(x[0]**2)*x[1] - math.sin(x[0]*x[1]) + math.cos(x[0]*x[0]) + c1*x[1]

# %%
x = np.array([1,2])
c0, c1 = (1,6)
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, f2, [eps, eps], c0, c1)
# Градиент функции в точки (1,2) совпадает с результатом ручного вычисления по у 
# и есть небольшая погрешность по х ( думаю за счет моего округления)
# Out:
# array([3.14935184, 7.41614687])

# %% [markdown]
# **Задание 2:**
# Градиентный спуск своими руками

# %%
f_str = '(x[0]**2) + (x[1]**2)'

# %%
x = np.array([100, 200])

# %%
def  F_grad(a):
    #x = Symbol('x')
    y = Symbol('y')

    z_d = eval (f_str) 

    yprime = z_d.diff(y)
    dif_y=str(yprime).replace('y', str(a[1]))
    dif_y=dif_y.replace('x', str(a[0]))

    yprime = z_d.diff(x)
    dif_x=str(yprime).replace('y', str(a[1]))
    dif_x=dif_x.replace('x', str(a[0]))

    return numpy.array([eval(dif_y), eval(dif_x)])

# %%
F_grad(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-25f8ced8a1a1> in <module>
# ----> 1 F_grad(x)
#
# <ipython-input-37-180ded84570f> in F_grad(a)
#       5     z_d = eval (f_str)
#       6
# ----> 7     yprime = z_d.diff(y)
#       8     dif_y=str(yprime).replace('y', str(a[1]))
#       9     dif_y=dif_y.replace('x', str(a[0]))
#
# AttributeError: 'numpy.int64' object has no attribute 'diff'

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
def fd(x):
    return 2*x[0] + 2*x[1]

# %%
x = np.array([100, 200])
learning_rate = 0.1

# %%
for i in range(100):
    # Calculate gradient
    grad = # Your code here (функция для вычисления градиента есть в лекционном ноутбуке)
    
    # Update x with gradient
    x = # Your code here (смотри слайд презентации про градиентный спуск)

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
Проверка с помощью встроенной функции numpy:

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10,7

# %%
import numpy
import math
from pylab import *
from sympy import *
from scipy.optimize import minimize_scalar
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d, Axes3D

z_str = ' a[0] ** 2 + a[1] ** 2'

exec ('z = lambda a: ' + z_str)

z_str = z_str.replace('a[0]', 'x')
z_str = z_str.replace('a[1]', 'y')

def z_grad(a):
    x = Symbol('x')
    y = Symbol('y')

    z_d = eval (  z_str) 

    yprime = z_d.diff(y)
    dif_y=str(yprime).replace('y', str(a[1]))
    dif_y=dif_y.replace('x', str(a[0]))

    yprime = z_d.diff(x)
    dif_x=str(yprime).replace('y', str(a[1]))
    dif_x=dif_x.replace('x', str(a[0]))

    return numpy.array([eval(dif_y), eval(dif_x)])

def mininize(a):
    l_min = minimize_scalar(lambda l: z(a - l * z_grad(a))).x
    q = (a - l_min * z_grad(a))
    print (q)
    return q

def norm(a):
    return math.sqrt(a[0] ** 2 + a[1] ** 2)

def grad_step(dot):
    return mininize(dot)

dot = [numpy.array([100.0, 200.0])]
dot.append(grad_step(dot[0]))

eps = 0.0001

while norm(dot[-2] - dot[-1]) > eps:
    dot.append(grad_step(dot[-1]))
    

    
def makeData ():
    x = numpy.arange (-200, 200, 1.0)
    y = numpy.arange (-200, 200, 1.0)
    xgrid, ygrid = numpy.meshgrid(x, y)
    zgrid = z([xgrid, ygrid])
    return xgrid, ygrid, zgrid

xt, yt, zt = makeData()

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(xt, yt, zt, cmap=cm.hot)
ax.plot([x[0] for x in dot], [x[1] for x in dot], [z(x) for x in dot], color='b')


plt.show()
# Out:
# [-60. 120.]
# [36. 72.]
# [-21.59999915  43.20000043]
# [12.96000017 25.92000162]
# [-7.77600051 15.55200179]
# [4.66560055 9.33120157]
# [-2.79936037  5.59872129]
# [1.6796164  3.35923313]
# [-1.00776995  2.01554009]
# [0.60466203 1.20932418]
# [-0.36279727  0.72559458]
# [0.21767837 0.43535677]
# [-0.13060703  0.26121408]
# [0.07836422 0.15672845]
# [-0.04701854  0.09403708]
# [0.02821112 0.05642225]
# [-0.01692668  0.03385335]
# [0.01015601 0.02031201]
# [-0.0060936   0.01218721]
# [0.00365616 0.00731232]
# [-0.0021937   0.00438739]
# [0.00131622 0.00263244]
# [-0.00078973  0.00157946]
# [0.00047384 0.00094768]
# [-0.0002843   0.00056861]
# [0.00017058 0.00034116]
# [-0.00010235  0.0002047 ]
# [6.14094804e-05 1.22818961e-04]
# [-3.68456882e-05  7.36913765e-05]
# [2.21074138e-05 4.42148255e-05]
