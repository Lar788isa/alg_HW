# %% [markdown]
# Задание
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции:
#     strategy, maxiter, popsize, tol, mutation, recombination и updating.

# %%
import numpy as np
from scipy.optimize import differential_evolution

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]# пределы изменения переменных
result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %%
result.x, result.fun
# Out:
# (array([0., 0.]), 4.440892098500626e-16)

# %% [markdown]
# strategystr, optional
# The differential evolution strategy to use. Should be one of:
#
# ‘best1bin’
#
# ‘best1exp’
#
# ‘rand1exp’
#
# ‘randtobest1exp’
#
# ‘currenttobest1exp’
#
# ‘best2exp’
#
# ‘rand2exp’
#
# ‘randtobest1bin’
#
# ‘currenttobest1bin’
#
# ‘best2bin’
#
# ‘rand2bin’
#
# ‘rand1bin’
#
# maxiterint, optional
# The maximum number of generations over which the entire population is evolved.
# The maximum number of function evaluations (with no polishing) is: (maxiter + 1) * popsize * len(x)

# %% [markdown]
# differential_evolution(func, bounds, args=(),
# strategy='best1bin', maxiter=1000, popsize=15, tol=0.01, mutation=(0.5, 1),
# recombination=0.7, seed=None, callback=None, disp=False,
# polish=True, init='latinhypercube', atol=0, updating='immediate', workers=1, constraints=())[source]

# %%
result = differential_evolution(ackley, bounds,strategy='best1exp', seed=42)
result
# Мы получили тот же результат, но количество итераций и вычислений функции было значительно больше чем при методе ‘best1bin’
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 4293
#      nit: 140
#  success: True
#        x: array([0., 0.])

# %%
result = differential_evolution(ackley, bounds,strategy='rand1exp', seed=42)
result
# Мы получили тот же результат, но количество итераций и вычислений функции значительно больше чем при методе ‘best1bin’ и best1exp
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 7323
#      nit: 241
#  success: True
#        x: array([0., 0.])

# %%
result = differential_evolution(ackley, bounds,strategy='randtobest1exp', seed=42)
result
# Этот метод более экономичен чем rand1exp
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 4893
#      nit: 160
#  success: True
#        x: array([0., 0.])

# %%
# Ограничем количество итераций 100
result = differential_evolution(ackley, bounds,strategy='best1exp',maxiter=100, seed=42)
result
# Конечный результат мы не получили  "success: False за 100 "
# Out:
#      fun: 1.0793588245405772e-11
#  message: 'Maximum number of iterations has been exceeded.'
#     nfev: 3093
#      nit: 100
#  success: False
#        x: array([-1.12465592e-12,  3.64597241e-12])

# %%
# Введем значение popsize 
result = differential_evolution(ackley, bounds,strategy='best1exp',maxiter=200,popsize=1, seed=42)
result
# Out:
#      fun: 0.0001721598226294141
#  message: 'Optimization terminated successfully.'
#     nfev: 420
#      nit: 47
#  success: True
#        x: array([-3.70318876e-05, -4.82625615e-05])

# %%
# popsize = 2
result = differential_evolution(ackley, bounds,strategy='best1exp',maxiter=200,popsize=2, seed=42)
result
# Out:
#      fun: 0.0001721598226294141
#  message: 'Optimization terminated successfully.'
#     nfev: 420
#      nit: 47
#  success: True
#        x: array([-3.70318876e-05, -4.82625615e-05])

# %%
#  Когда ограничиваем popsize мы получаем разные результаты 
result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize=2, seed=42)
result
# Out:
#      fun: 2.5799275570299085
#      jac: array([-1.42108547e-06, -1.06581410e-06])
#  message: 'Optimization terminated successfully.'
#     nfev: 103
#      nit: 7
#  success: True
#        x: array([-2.86743508e-08,  9.52166523e-01])

# %%
# Результат верен с popsize выше 5
result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize=5, seed=42)
result
# Получаем, что если значение больше 5 то nit уменьшается, а  nfev увеличивается. Результат не меняется
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1073
#      nit: 100
#  success: True
#        x: array([0., 0.])

# %%
# ПРи этом методе , увеличение popsize приводит к увеличению количества и nfev и nit
result = differential_evolution(ackley, bounds,strategy='best1exp',maxiter=200,popsize=5, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1433
#      nit: 136
#  success: True
#        x: array([0., 0.])

# %%
# Вводим tol = 0.01 (тот же результат), И при увеличении точности , результат наших вычислений не меняется
result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize= 5 ,tol= 1, seed=42)
result
#  при tol = 0.1 Появилось новое сообщение jac со значениями array([-1.54587383,  1.31143807])
#  при tol = 1 Появилось новое сообщение jac со значениями array([4.61852778e-05, -7.31859018e-05]])
# и мы дальше уходим от нужного результата функции
# Out:
#      fun: 2.57992755710594
#      jac: array([ 4.61852778e-05, -7.31859018e-05])
#  message: 'Optimization terminated successfully.'
#     nfev: 65
#      nit: 1
#  success: True
#        x: array([ 8.29671557e-07, -9.52168097e-01])

# %%
# Вводим mutation=(0.5, 1) (тот же результат), nfev: 1073  nit: 100
# Увеличение константы мутации увеличивает радиус поиска, но замедляет сходимость. Она не выходит за рамки [0, 2)
result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize= 5 ,tol= 0.01,
mutation=(1.5, 1.5),seed=42)
result
#  mutation=(1, 1) Значение функ не верно - nfev: 181  nit: 15
# mutation=(0.5 , 0.5) Значение не верное - nfev: 703 nit: 63
# при mutation=(0, 0) сново появилось значение jac , nfev: 51 nit: 2
# mutation=(1.9, 1.9) мы быстро получили верный ответ, но есть jac , nfev: 753 nit: 62
# Out:
#      fun: 1.915963965259948e-08
#      jac: array([0.08816485, 0.08343655])
#  message: 'Optimization terminated successfully.'
#     nfev: 560
#      nit: 40
#  success: True
#        x: array([-4.78399065e-09, -4.79582173e-09])

# %%
#  recombination=0.7.  В пределах (0.1) Увеличение этого значения позволяет большему количеству мутантов прогрессировать
# в следующее поколение, но с риском для стабильности популяции.

result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize= 5 ,tol= 0.01,
mutation=(0.5, 1), recombination=0.5, seed=42)
result

# recombination=0.7 - значение аналогичное
# recombination=0 - nfev: 1313  nit: 124 - больше итераций 
# recombination=1 мы получили не верное решение задачи 
# recombination=0.5  1243 nit: 117
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 1243
#      nit: 117
#  success: True
#        x: array([0., 0.])

# %%
#  updating='immediate' Если 'immediate'лучший вектор решения постоянно обновляется в течение одного поколения.
# При 'deferred' вектор наилучшего решения обновляется один раз за поколение. 

result = differential_evolution(ackley, bounds,strategy='best1bin', maxiter=200,popsize= 5 ,tol= 0.01,
mutation=(0.5, 1), recombination=0.7, seed=42, updating='deferred')
result

# updating='immediate' наше решение получаем 
# deferred мы получили не верное решение задачи. Для этого метода такая опция не подходит
# Out:
#      fun: 1.6621333149835493e-06
#  message: 'Optimization terminated successfully.'
#     nfev: 730
#      nit: 57
#  success: True
#        x: array([-5.53615376e-09, -5.87623539e-07])

# %% [markdown]
# **Постройте графики количества итераций оптимизации функции ackley от значения параметра.**

# %%
def ackley1(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]# пределы изменения переменных
result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Построю функцию
def ackley (x, y):
    arg1 = -0.2 * np.sqrt(0.5 * (x**2 + y**2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x) + np.cos(2. * np.pi * y))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

# %%
# создаём полотно для рисунка
fig = plt.figure(figsize = (10, 10))
# создаём рисунок пространства с поверхностью
ax = fig.add_subplot(1, 1, 1, projection = '3d')
# размечаем границы осей для аргументов
xval = np.linspace(-10, 10, 100)
yval = np.linspace(-10, 10, 100)
# создаём массив с xval столбцами и yval строками
# - в этом массиве будут храниться значения z
x, y = np.meshgrid(xval, yval)
# приравниваем z к функции от x и y 
z = ackley(x, y)
# создаём поверхность
surf = ax.plot_surface(
# отмечаем аргументы и уравнение поверхности
x, y, z, 
# шаг прорисовки сетки
# - чем меньше значение, тем плавнее
# - будет градиент на поверхности
rstride = 5,
cstride = 5,
# цветовая схема plasma
cmap = cm.plasma)

# %%
# создаём полотно для рисунка
fig = plt.figure(figsize = (10, 10))
# создаём рисунок пространства с поверхностью
ax = fig.add_subplot(1, 1, 1, projection = '3d')
# размечаем границы осей для аргументов
xval = np.linspace(-4, 4, 50)
yval = np.linspace(-4, 4, 50)
# создаём массив с xval столбцами и yval строками
# - в этом массиве будут храниться значения z
x, y = np.meshgrid(xval, yval)
# приравниваем z к функции от x и y 
z = ackley(x, y)
# создаём поверхность
surf = ax.plot_surface(
# отмечаем аргументы и уравнение поверхности
x, y, z, 
# шаг прорисовки сетки
# - чем меньше значение, тем плавнее
# - будет градиент на поверхности
rstride = 5,
cstride = 5,
# цветовая схема plasma
cmap = cm.plasma)

# %%
def ackley1(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]# пределы изменения переменных
result = differential_evolution(ackley, bounds, seed=42)
fun1 = result['fun']

# %%
fun1
# Out:
# 4.440892098500626e-16

# %%
# создаём полотно для рисунка
fig = plt.figure(figsize = (10, 10))
# создаём рисунок пространства с поверхностью
ax = fig.add_subplot(1, 1, 1, projection = '3d')
# размечаем границы осей для аргументов
x[0] = np.linspace(-4, 4, 50)
x[1] = np.linspace(-4, 4, 50)

# создаём массив с xval столбцами и yval строками
x = np.meshgrid(x[0],x[1])

# вычисляем значение функции в точки х
result = differential_evolution(ackley1(x), bounds, seed=42)
fun1 = result['fun']
# создаём поверхность
surf = ax.plot_surface(

x[0], x[1], fun1, 

rstride = 5,
cstride = 5,
cmap = cm.plasma)

#  НЕ могу понять как построить данный график
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in _calculate_population_energies(self, population)
#     877             calc_energies = list(self._mapwrapper(self.func,
# --> 878                                                   parameters_pop[0:nfevs]))
#     879             energies[0:nfevs] = calc_energies
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/_differentialevolution.py in __call__(self, x)
#    1264     def __call__(self, x):
# -> 1265         return self.f(x, *self.args)
#    1266
#
# TypeError: 'numpy.ndarray' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-189-6c7b5d49334f> in <module>
#      11
# ...
